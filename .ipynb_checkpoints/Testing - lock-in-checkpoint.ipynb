# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as scisig
import scipy.optimize as opt
import scipy.io as sio
import analysis_utils as au
import simulation_utils as su
import importlib

# %%
# Define some parameters

w0 = 55000*2*np.pi # Natural frequency of oscillator
P = 1*10**(-7) # Pressure in mbar
T = 293 # Environmental temperature
R = (0.083)*10**(-6) # Particle Radius
p = 2200 # Particle Denisty
dtn = 1*10**(-8) # Timestep
M = 4/3*np.pi*R**3*p # Particle mass
kb = 1.38*10**(-23) # Boltzmann constant
m = 29*1.67*10**(-27) # average mass of air particles
v = np.sqrt(8*1.38*10**(-23)*T/(np.pi*m)) # velocity of air particles
N0 = 2.43*10**(25) # Number density of air and ambient pressure
P0 = 1000 # Ambient pressure
N=N0*P/P0 # Number density of air at pressure P

y = (4/3*np.pi)*(m*v*N*R**2)/(M) # Damping from air
#y = 4.10568*1e-6*P*1e2/R # Antonio's damping from air

print(y)

Snn = 10**(-26) # Displacement noise
# Out:
# 0.00029717080823618027

# %%
maxw = 5*10**5 # 500 kHz is enough to capture all dynamics
yfb = 1*2*np.pi
numbins = int(2*5*10**4*100*2*np.pi/yfb) # This is to ensure the particle amplitude decays to thermal levels
w = np.linspace(0, maxw*2*np.pi, numbins)

# Generate some random number seeds
np.random.seed(85655219)
random_nums = np.random.uniform(0, 1000000, 3) # These are the seeds we will use

randomlist, randomlist2, randomlist3 = su.generate_random_numbers(random_nums[0:3], Snn, numbins, maxw)
x = su.generate_displacement_fm(w, w0, y, yfb, M, T, randomlist, randomlist2, randomlist3, np.zeros(numbins), 0.1, 0)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[278], line 11
#       8 random_nums = np.random.uniform(0, 1000000, 3) # These are the seeds we will use
#      10 randomlist, randomlist2, randomlist3 = su.generate_random_numbers(random_nums[0:3], Snn, numbins, maxw)
# ---> 11 x = su.generate_displacement_fm(w, w0, y, yfb, M, T, randomlist, randomlist2, randomlist3, np.zeros(numbins), 0.1, 0)
#
# File c:\Users\thoma\OneDrive\Documents\SIMPLE\Nanoparticle\Scripts\Simulations\SIMPLE_impulsesimulations\simulation_utils.py:191, in generate_displacement_fm(w, w0, y0, yfb, M, T, rnd, rnd2, rnd3, ir, iter, phase)
#     189 # Generate frequency response of particle
#     190 thermal_response = transfer_function2(w, w0, y0, yfb, rnd, rnd2, M, T)
# --> 191 x = np.fft.irfft(thermal_response)[int(numbins/2-1):-int(numbins/2-1)] # Reverse fourier transform to time domain and throw away start and end to get rid of finite time effects
#     192 x = x*np.sqrt(np.trapz(np.abs(thermal_response**2), w/2/np.pi)/np.var(x)) # Scale to correct units
#     193 time = np.linspace(0, np.pi/w[-1]*numbins, numbins)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numpy\fft\_pocketfft.py:513, in irfft(a, n, axis, norm)
#     511     n = (a.shape[axis] - 1) * 2
#     512 inv_norm = _get_backward_norm(n, norm)
# --> 513 output = _raw_fft(a, n, axis, True, False, inv_norm)
#     514 return output
#
# File c:\ProgramData\anaconda3\Lib\site-packages\numpy\fft\_pocketfft.py:70, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      67         a = z
#      69 if axis == a.ndim-1:
# ---> 70     r = pfi.execute(a, is_real, is_forward, fct)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
#
# MemoryError:

# %%
randomlist, randomlist2, randomlist3 = su.generate_random_numbers(random_nums[0:3], Snn, numbins, maxw)
x = np.sin(55000*2*np.pi*np.linspace(0, 10, 10**7)) + randomlist3

# %%
PSD = scisig.welch(x, fs = 10**6, nperseg = 10**7)

# %%
lb = int(10*54000)
ub = int(10*56000)
plt.plot(PSD[0][lb:ub], PSD[1][lb:ub])
plt.yscale('log')

# %%
time, R2, R2_filt, theta_filt = au.lockin(x[:10**7], 10**6, 55000, 100, 20000, 100, 'R')

# %%
plt.plot(np.unwrap(theta_filt%(2*np.pi)))

# %%
lb = int(4.844*10**6)
ub = lb +10000
plt.plot(np.gradient(theta_filt, 10**(-6))[lb:ub]/2/np.pi)
plt.plot(theta_filt[lb:ub]*10)
plt.plot((theta_filt[lb-1:ub-1]+np.gradient(theta_filt, 10**(-6))[lb:ub]/10**6)*10)

# %%
10-4.844
# Out:
# 5.156

# %%
lb = int(4.844*10**6)
ub = lb+10000
plt.plot((55000*2*np.pi+(theta_filt[1:] - theta_filt[:-1])*10**6)[lb:ub]/2/np.pi)

# %%
lb = -int(5.156*10**6)
ub = lb+1000 
plt.figure(figsize = (20, 7))
plt.plot(x[lb:ub]*10**9)
#plt.plot(np.sin((55000*2*np.pi+theta_filt[:-1]+(theta_filt[1:] - theta_filt[:-1])*10**6)*np.linspace(2*10**(-6), 10, 10**7-2))[lb:ub])
plt.plot(np.sin((55000*2*np.pi)*np.linspace(1*10**(-6), 10, 10**7-1)+theta_filt)[lb:ub])

# %%
np.std((theta_filt[1:] - theta_filt[:-1])*10**6/2/np.pi/2)
# Out:
# 0.26801164045959797
